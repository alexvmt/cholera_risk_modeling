# %% [markdown]
# # Preprocess cholera outbreaks

# %% [markdown]
# This notebook executes a Python script to download weekly cholera outbreaks data in PDF format from the [Integrated Disease Surveillance Programme of India](https://idsp.nic.in/) (IDSP). It then cleans and prepares the data and saves it in shapefile format for further processing.

# %%
# import packages
import os
import numpy as np
import pandas as pd
import PyPDF2
import re
import geopandas as gpd
import requests
import zipfile
import io

# %% [markdown]
# ## Download cholera outbreaks data

# %% [markdown]
# Run Python script to download cholera outbreaks data. Before downloading a file the script checks whether that file has already been downloaded or not.

# %%
# !python download_cholera_outbreaks_data.py
# Out:
# Download cholera outbreaks data...
# Processing 2010 with 53 files...
# Processing 2011 with 52 files...
# Processing 2012 with 52 files...
# Processing 2013 with 52 files...
# Processing 2014 with 52 files...
# Processing 2015 with 53 files...
# Processing 2016 with 52 files...
# Processing 2017 with 52 files...
# Processing 2018 with 52 files...
# Download cholera outbreaks data complete.

# %% [markdown]
# ## Load PDFs and extract relevant parts

# %%
# make list of desired years
years = list(np.arange(2010, 2019))

# %%
# set path for cholera outbreaks data
path = '../data/cholera_outbreaks'

# %% [markdown]
# Next, all PDFs are loaded in a for loop and the relevant information is extracted.

# %%
# %%time

outbreaks_raw = []

for year in years:
    print('Processing year: {}...'.format(year))
    (_, _, file_names) = next(os.walk(os.path.join(path, str(year)))) # get all file names in directory
    
    for file in file_names:
        print('Processing file: {}...'.format(file))
        document = PyPDF2.PdfFileReader(os.path.join(path, str(year), file)) # load pdf
        pages = document.getNumPages() # get number of pages
        
        for page in range(pages):
            text = document.getPage(page).extractText() # extract raw text from pdf
            text = text.replace('\n', '') # remove line breaks
            text = text.split(' ') # split on space
            text = [i for i in text if i != ''] # remove empty items
            text = [i.lower() for i in text] # lower case all items
    
            indices = [i for i, s in enumerate(text) if 'cholera' in s] # get indices where cholera is mentioned
        
            # if cholera is mentioned on page proceed with extraction of information        
            if len(indices) > 0:
                for index in indices:
                    cholera_index = []
                    cholera_index.append(index) # get index where cholera is mentioned
                    index_list = np.arange(index-3,index).tolist() + cholera_index + np.arange(index+1,index+5).tolist() # construct list to extract neighboring information
                    index_list = [i for i in index_list if i < len(text)] # get items that are up to 3 indices before and up to 5 indices after where the index where cholera is mentioned
                    outbreak_info = [text[i] for i in index_list]
                    # append extracted information to temporary list
                    while len(outbreak_info) < 9:
                        outbreak_info.append(None)
                    # append file name to temporary list
                    outbreak_info.append(str(year)+'/'+file)
                    # append extracted information to final list
                    outbreaks_raw.append(outbreak_info)
            # continue otherwise
            else:
                pass
# Out:
# Processing year: 2010...
# Processing file: 31st_2010.pdf...
# Processing file: 3rd_2010.pdf...
# Processing file: 5th_2010.pdf...
# Processing file: 42nd_2010.pdf...
# Processing file: 39th_2010.pdf...
# Processing file: 41st_2010.pdf...
# Processing file: 27th_2010.pdf...
# Processing file: 53rd_2010.pdf...
# Processing file: 9th_2010.pdf...
# Processing file: 33rd_2010.pdf...
# Processing file: 25th_2010.pdf...
# Processing file: 28th_2010.pdf...
# Processing file: 14th_2010.pdf...
# 0      under  None  2010/31st_2010.pdf
# 1          9  None  2010/31st_2010.pdf
# 2      under  None  2010/31st_2010.pdf
# 3  serotype)  None  2010/31st_2010.pdf
# 4   10.09.10  None  2010/39th_2010.pdf

# %%
# rename columns
column_names = []

for i in range(outbreaks_raw.shape[1]):
    column_names.append('col'+str(i))

outbreaks_raw.columns = column_names

# %%
outbreaks_raw.head()
# Out:
#        col0       col1    col2      col3    col4       col5      col6  \
# 0  himachal    pradesh  shimla   cholera    235/         1*  13.07.10
# 1  positive        for      v.  cholerae  (ogawa  serotype)       and
# 2    alwar,     sikar,  jaipur   cholera  1095/0          #  20.07.10
# 3    growth         of      v.  cholerae     (el        tor    -ogawa
# 4     assam  dibrugarh    xvi.   cholera      10          /         0
#
#         col7  col8                col9
# 0      under  None  2010/31st_2010.pdf
# 1          9  None  2010/31st_2010.pdf
# 2      under  None  2010/31st_2010.pdf
# 3  serotype)  None  2010/31st_2010.pdf
# 4   10.09.10  None  2010/39th_2010.pdf

# %%
# check which columns contain cholera 
for i in range(outbreaks_raw.shape[1]):
    print('Column {} contains cholera: {}'.format(i, 'cholera' in outbreaks_raw.iloc[:,i].unique()))
# Out:
# Column 0 contains cholera: True
# Column 1 contains cholera: False
# Column 2 contains cholera: False
# Column 3 contains cholera: True
# Column 4 contains cholera: True
# Column 5 contains cholera: False
# Column 6 contains cholera: False
# Column 7 contains cholera: False
# Column 8 contains cholera: False
# Column 9 contains cholera: False

# %% [markdown]
# Check out the rows where cholera is mentioned in different columns to better understand the structure of the extracted information.

# %%
outbreaks_raw.loc[outbreaks_raw['col0'] == 'cholera']
# Out:
#         col0     col1 col2      col3     col4    col5  col6       col7  col8  \
# 268  cholera  culture  (v.  cholerae  ogawa).  health  camp  conducted  None
#
#                    col9
# 268  2011/36th_2011.pdf

# %%
outbreaks_raw.loc[outbreaks_raw['col3'] == 'cholera']
# Out:
#                     col0         col1    col2     col3      col4      col5  \
# 0               himachal      pradesh  shimla  cholera      235/        1*
# 2                 alwar,       sikar,  jaipur  cholera    1095/0         #
# 4                  assam    dibrugarh    xvi.  cholera        10         /
# 5                 growth           of  vibrio  cholera        01        on
# 7              karnataka      belgaum    xxi.  cholera        19         /
# ...                  ...          ...     ...      ...       ...       ...
# 2058            positive          for      v.  cholera      sero      type
# 2060               delhi        north   delhi  cholera        12        00
# 2061            positive          for      v.  cholera        01        by
# 2062  mh/nas/2018/27/961  maharashtra  nashik  cholera       195  03(55/m,
# 2064               found     negative     for  cholera  culture.        02
#
#           col6      col7  col8                col9
# 0     13.07.10     under  None  2010/31st_2010.pdf
# 2     20.07.10     under  None  2010/31st_2010.pdf
# 4            0  10.09.10  None  2010/39th_2010.pdf
# 5      culture        at  None  2010/39th_2010.pdf
# 7            0  06.09.10  None  2010/39th_2010.pdf
# ...        ...       ...   ...                 ...
# 2058    ogawa.     three  None   2018/8th_2018.pdf
# 2060  06-07-18     under  None  2018/31st_2018.pdf
# 2061   culture        in  None  2018/31st_2018.pdf
# 2062     65/m,     30/f)  None  2018/31st_2018.pdf
# 2064     water   samples  None   2018/1st_2018.pdf
#
# [1259 rows x 10 columns]

# %%
outbreaks_raw.loc[outbreaks_raw['col4'] == 'cholera']
# Out:
#          col0 col1    col2       col3     col4   col5      col6 col7  col8  \
# 115  positive  for  vibrio  cholerae.  cholera  cases  occurred  due  None
#
#                    col9
# 115  2010/29th_2010.pdf

# %%
outbreaks.col9.nunique()
# Out:
# 273

# %%
# check which columns contain cholera
cholera_columns = [column for column in outbreaks_raw if outbreaks_raw[column].str.contains('cholera', na=False).any()]
cholera_columns
# Out:
# ['col0', 'col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7']

# %%
# check which columns contain how many cholera rows
for cholera_column in cholera_columns:
    print('Number of cholera rows in {}: {}'.format(cholera_column, outbreaks_raw[outbreaks_raw[cholera_column].str.contains('cholera', na=False)].shape[0]))
# Out:
# Number of cholera rows in col0: 1
# Number of cholera rows in col1: 1
# Number of cholera rows in col2: 1
# Number of cholera rows in col3: 2065
# Number of cholera rows in col4: 1
# Number of cholera rows in col5: 1
# Number of cholera rows in col6: 1
# Number of cholera rows in col7: 1

# %%
outbreaks_raw[outbreaks_raw['col0'].str.contains('cholera', na=False)]
# Out:
#         col0     col1 col2      col3     col4    col5  col6       col7  col8  \
# 268  cholera  culture  (v.  cholerae  ogawa).  health  camp  conducted  None
#
#                    col9
# 268  2011/36th_2011.pdf

# %%
outbreaks_raw[outbreaks_raw['col1'].str.contains('cholera', na=False)]
# Out:
#      col0      col1    col2      col3     col4      col5 col6  col7  col8  \
# 2051  for  cholera,  vibrio  cholerae  (ogawa)  positive   at  dphl  None
#
#                     col9
# 2051  2018/23rd_2018.pdf

# %%
outbreaks_raw[outbreaks_raw['col2'].str.contains('cholera', na=False)]
# Out:
#     col0    col1       col2     col3   col4      col5 col6 col7  col8  \
# 116  for  vibrio  cholerae.  cholera  cases  occurred  due   to  None
#
#                    col9
# 116  2010/29th_2010.pdf

# %%
outbreaks_raw[outbreaks_raw['col4'].str.contains('cholera', na=False)]
# Out:
#          col0 col1    col2       col3     col4   col5      col6 col7  col8  \
# 115  positive  for  vibrio  cholerae.  cholera  cases  occurred  due  None
#
#                    col9
# 115  2010/29th_2010.pdf

# %%
outbreaks_raw[outbreaks_raw['col5'].str.contains('cholera', na=False)]
# Out:
#        col0     col1 col2      col3    col4      col5     col6      col7  \
# 2050  stool  culture  for  cholera,  vibrio  cholerae  (ogawa)  positive
#
#       col8                col9
# 2050  None  2018/23rd_2018.pdf

# %%
outbreaks_raw[outbreaks_raw['col6'].str.contains('cholera', na=False)]
# Out:
#      col0      col1 col2     col3     col4 col5      col6     col7  col8  \
# 267  were  positive  for  cholera  culture  (v.  cholerae  ogawa).  None
#
#                    col9
# 267  2011/36th_2011.pdf

# %%
outbreaks_raw[outbreaks_raw['col7'].str.contains('cholera', na=False)]
# Out:
#      col0      col1 col2     col3 col4     col5 col6      col7  col8  \
# 659  were  positive  for  cholera  (01  ogawa).  ii.  cholera?  None
#
#                    col9
# 659  2013/45th_2013.pdf

# %%
outbreaks_raw['col3'].unique()
# Out:
# array(['cholera', 'cholerae', 'cholerae.', 'cholera.', 'v.cholerae.',
#        'cholera?', 'v.cholerae', 'v.cholera.', "v.cholerae-'eltor'",
#        'v.cholera', 'cholera;', 'cholera,', '?cholera', 'cholera??',
#        'cholerae,', 'vibrio-cholera.', 'vi.cholera', 'xxiii.cholera',
#        'xxvi.cholera', 'feverchickenpoxchikungunyacholeraacute',
#        'fever/puodenguechikungunyacholeramalariamumpsenteric',
#        'hepatitisdenguechikungunyacholeramalariamumpsacute',
#        'hepatitisdenguecholerachikungunyamalariaacute', 'xii.cholera?',
#        'cholera.02', 'hepatitisdenguechikungunyacholeramalariaacute',
#        'fevercholerachickenpoxmalariachikungunya', 'cholera.04',
#        'poisoningfeverchickenpoxchikungunyajapaneseencephalitismalariacholeradenguehepatitis',
#        'hepatitisdenguechikungunyacholeramalariamumpsenteric',
#        'adiphtheriameasleschickungunyacholerajapanese–hand',
#        'hepatitisdenguecholerachikungunyamalariano.',
#        'ameaslescholerafeverfood',
#        'diarrhoeal–measlesmalariachikungunyadiphtheriafevermeasles?denguecholeraviral',
#        'rashchikungunyacholeradiphtheria643332222111no.',
#        'acholerachickungunyameasleschickenpoxmumpshepatitis',
#        'typhuschikungunyamalariacholerafeverfever', 'cholera.16',
#        '–measlesdenguechikunpoxcholeramalariafeverjaundicemumpsdiarrhoeachikungunyafever',
#        'poisoningfevercholerachickungunyameaslesscrub',
#        'achikungunyafeverdenguemeasleschickenpoxcholeramalariacchfscrub',
#        'poisoningmalariameaslescchfcholerajapanese', '.cholerae',
#        'diarrheal–jaundicedenguecholeraviral',
#        'poisoningcchfchickenpoxchikungunyacholeradenguediarrheadiphtheriadysenteryenteric',
#        'poisoningcholeraacute',
#        'poisoningcchfchickenpoxchikungunyacholerachandipura',
#        'diarrheal–denguecholeraviral',
#        'rashcchfrubellacholeradysenteryleptospirosispam',
#        'seed–cchfchickenpoxchikungunyacholeradenguediarrheadiphtheriadysenteryenteric',
#        'hepatitischolerachikungunyamalariamumpsacute',
#        'adiphtheriaacute–cholera15139653322111111no.',
#        'poisoninganthraxcchfchickenpoxchikungunyacholeradenguediphtheriaenteric',
#        'seed–cchfchickenpoxchikungunyacholerachandipura',
#        'illnesscholerafever', 'fevercholera177543322221111111no.',
#        'rashanthraxcholeradiarrheadysentryleptospirosiskyasanur',
#        'encephalitis–brucellosiscchfchickenpoxchikungunyacholeradenguediarrheadiphtheriadysenteryenteric',
#        'poisoningmeasleschickenpoxcholerahepatitis',
#        'rashcholeramumpsdenguechikungunyaanthraxcchfrubellahepatitis',
#        'jatropha–cchfchickenpoxchikungunyacholeradenguediphtheriaenteric',
#        'poisoningcholeramalariadenguehepatitis-arubellaviral',
#        'poisoningcchfchickenpoxchikungunyacholeradenguediarrheadiphtheriadysenterydrug',
#        'diseasedenguecholeraviral',
#        'diarrheal–measlesdenguecholeramumpsanthraxjaundicehepatitis-ahepatitis-eacute',
#        'ejaundicecholeramumps16129222111111no.',
#        'poisoningcchfchickenpoxchikungunyacholeradenguediphtheriaenteric',
#        'poisoningcholeradiphtheriajaundiceviral',
#        '(n=26)012345678acute–chickenpoxchikungunyacholeradenguediphtheriameaslesfood',
#        'diseasechickenpoxcholeradenguemeaslesfood',
#        'poisoningcholerachickenpoxacute', 'cholera.out',
#        'diseasefeverdenguecholerameasleshepatitis',
#        'encephalitis–cchfchickenpoxchikungunyacholeradenguediarrheadiphtheriaenteric',
#        'diseasecholerafood',
#        'poisoningmeaslescholeradenguemumpsanthraxhepatitis-amalariatyphoidrubellajapanese',
#        'poisoningchickenpoxfeverchikungunyacholerameaslesfood',
#        'dysenterydiphtheriacholera2092221111111111no.',
#        'diseasechickenpoxchikungunyacholeracrimean',
#        'gastroenteritischoleradengueanthraxviral',
#        'poisoningdenguemeasleschikungunyacholeradiphtheriafeverchickenpoxrubellascrub',
#        'poisoningdenguecholerameasleshepatitis-arubellaenteric',
#        'poisoningchickenpoxchikungunyacholeradenguediphtheriameaslesfood',
#        'poisoningcholerafeveracute',
#        'amumpschickenpoxchikungunyajaundiceleptospirosisdiphtheriadiarrheacholeraacute',
#        'diarrheal–chickenpoxdengueanthraxrubellameaslescholerapertusismumpshepatitis-a&echickungunyadiphtheriafever16151553332211111no.',
#        'ajaundiceleptospirosismumpsrubellacchfanthraxcholera66543222111111111no.',
#        'aaes/jecholerachikungunyarubellafeverjapanese',
#        'gastroenteritisfeverchickenpoxcholerachikungunyahepatitis',
#        'poisoningchickenpoxdenguemeaslescholerachikungunyaacute',
#        'cholerae01,', 'rashacute–mumpsrubellacholerafeverdenguehepatitis',
#        'gastroenteritisdenguecholerameasleshepatitis',
#        'diseasechickenpoxchikungunyacholeradenguediarrheadiphtheriadysenteryenteric',
#        'poisoningdenguechickungunyacholerahepatitis',
#        'dysenteryshigellosispertussischoleraacute',
#        'leptospirosiscchfcholeraacute',
#        'diarrhealdiseasedenguecholerafevermalaria',
#        'poisoningchickenpoxcholerahepatitis',
#        'measleschickungunyacholerachickenpoxmeasles',
#        'gastroenteritismalariacholeratyphusfalciparum',
#        'poisoningdenguechickenpoxcholeraacute', 'cholera.200',
#        'diseasefeverchikungunyacholerameasleshepatitis',
#        'diarrhealdiseasemeaslescholera?no.', 'rubellacholeracutaneous',
#        'poisoningcholeravivax', 'malariacholerafever', 'fevercholerano.',
#        'measleschikungunyashigellosischickenpoxmeaslescholerasuspected',
#        'mumpscholerameaslesjapanese', 'typhuscholerajapanese',
#        'poisoningcholerachickenpoxsuspected',
#        'poisoningcholera?measlesmalariano.',
#        'feverchikungunyacholeramalariamumpsfever', 'rashcholeraviral',
#        'poisoningmumpscholerajapaneseencephalitisviral',
#        'hepatitischolerachikungunyaviral', 'typhoidcholera?no.',
#        'fevercholeramalariamumpsacute',
#        'feverchikungunyacholeramalariamumpsacute',
#        'hepatitischoleraviral',
#        'poisoningchikungunyachickenpoxjapaneseencephalitismumps?cholerachickenpoxviral',
#        'diarrhealdiseasecholeradenguejapaneseencephalitisviral',
#        'acholerachickenpoxmeaslesfeverzika'], dtype=object)

# %% [markdown]
# The column to focus on is col4. The rows where cholera is mentioned in other columns don't seem to be relevant as they are not the outbreak information we look for.

# %% [markdown]
# ## Clean main cholera column

# %% [markdown]
# The main cholera column col4 contains in many cases much more than just a pure cholera string. Thus, all characters but cholera are removed.

# %%
outbreaks_raw['col3'].value_counts()
# Out:
# cholera                                                   1259
# cholera.                                                   268
# cholerae                                                   102
# cholerae.                                                   77
# cholera?                                                    41
#                                                           ...
# leptospirosiscchfcholeraacute                                1
# vibrio-cholera.                                              1
# poisoningdenguecholerameasleshepatitis-arubellaenteric       1
# diarrheal–denguecholeraviral                                 1
# typhuscholerajapanese                                        1
# Name: col3, Length: 125, dtype: int64

# %%
outbreaks_raw['col3_clean'] = outbreaks_raw['col3'].apply(lambda x: 'cholera' if 'cholera' in x else x)

# %%
outbreaks_raw['col3_clean'].value_counts()
# Out:
# cholera    2065
# Name: col3_clean, dtype: int64

# %% [markdown]
# ## Filter outbreaks

# %% [markdown]
# We know that a cholera outbreak is mentioned when we see cholera in col4 and a number of cases and/or deaths right next to it. Therefore, we filter the rows that satisfy this condition.

# %%
# next to where a cholera outbreak is mentioned there should be a number indicating the cases and/or deaths
outbreaks_raw['outbreak'] = outbreaks_raw['col4'].apply(lambda x: 0 if re.search('[a-zA-Z]', str(x)) else 1)

# %%
# filter dataframe where an outbreaks appears to be mentioned
outbreaks = outbreaks_raw.loc[outbreaks_raw['outbreak'] == 1].reset_index(drop=True)

# %%
outbreaks_raw.loc[outbreaks_raw['outbreak'] == 0].reset_index(drop=True)
# Out:
#            col0      col1    col2       col3         col4       col5  \
# 0      positive       for      v.   cholerae       (ogawa  serotype)
# 1        growth        of      v.   cholerae          (el        tor
# 2      negative       for      v.  cholerae.        water    samples
# 3        tested  positive     for   cholera.  alternative       safe
# 4     infection      with  vibrio    cholera          and    culture
# ...         ...       ...     ...        ...          ...        ...
# 1375       were  negative     for    cholera     culture.        all
# 1376        was  negative     for    cholera     culture.          3
# 1377   positive       for      v.    cholera         sero       type
# 1378  shigella,       and  vibrio   cholera.        water    samples
# 1379      found  negative     for    cholera     culture.         02
#
#             col6       col7  col8                col9  outbreak
# 0            and          9  None  2010/31st_2010.pdf         0
# 1         -ogawa  serotype)  None  2010/31st_2010.pdf         0
# 2      collected        for  None  2010/39th_2010.pdf         0
# 3       drinking      water  None  2010/39th_2010.pdf         0
# 4     senstivity      test,  None  2010/41st_2010.pdf         0
# ...          ...        ...   ...                 ...       ...
# 1375       cases    treated  None  2018/38th_2018.pdf         0
# 1376       water    samples  None  2018/38th_2018.pdf         0
# 1377      ogawa.      three  None   2018/8th_2018.pdf         0
# 1378        were        non  None  2018/31st_2018.pdf         0
# 1379       water    samples  None   2018/1st_2018.pdf         0
#
# [1380 rows x 11 columns]

# %%
outbreaks_raw.loc[outbreaks_raw['outbreak'] == 0].reset_index(drop=True).to_csv('temp.csv', index=False)

# %%
outbreaks.shape
# Out:
# (685, 11)

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3     growth         of  vibrio  cholera      01   on   culture        at
# 4  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
#
#    col8                col9 col3_clean  outbreak
# 0  None  2010/31st_2010.pdf    cholera         1
# 1  None  2010/31st_2010.pdf    cholera         1
# 2  None  2010/39th_2010.pdf    cholera         1
# 3  None  2010/39th_2010.pdf    cholera         1
# 4  None  2010/39th_2010.pdf    cholera         1

# %%
outbreaks.tail()
# Out:
#                     col0         col1        col2      col3 col4      col5  \
# 680  kl/mlp/2018/08/0241       kerala  malappuram   cholera   03        00
# 681                delhi        north       delhi   cholera   12        00
# 682             positive          for          v.   cholera   01        by
# 683   mh/nas/2018/27/961  maharashtra      nashik   cholera  195  03(55/m,
# 684             positive          for      vibrio  cholerae    &       all
#
#          col6      col7  col8                col9 col3_clean  outbreak
# 680  01-02-18     under  None   2018/8th_2018.pdf    cholera         1
# 681  06-07-18     under  None  2018/31st_2018.pdf    cholera         1
# 682   culture        in  None  2018/31st_2018.pdf    cholera         1
# 683     65/m,     30/f)  None  2018/31st_2018.pdf    cholera         1
# 684   samples  negative  None  2018/31st_2018.pdf    cholera         1

# %% [markdown]
# The rows that we suspect to mention outbreaks appear to be fine in many cases, but not all as we will see later.

# %% [markdown]
# ## Extract and clean start dates

# %% [markdown]
# Now we need to extract and clean the start dates of outbreaks. We know that the start date of an outbreak is supposed to be mentioned right next to the number of cases and/or deaths.

# %%
# clean columns suspected to contain start dates
for col in outbreaks.columns[5:8]:
    outbreaks[col+'_clean'] = outbreaks[col].apply(lambda x: None if re.search('[a-zA-Z]', str(x)) is not None
                                                   else (None if len(str(x)) < 4
                                                         else x.replace('(', '').replace(')', '').replace('*', '')))

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3     growth         of  vibrio  cholera      01   on   culture        at
# 4  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/39th_2010.pdf    cholera         1       None       None
#
#   col7_clean
# 0       None
# 1       None
# 2   10.09.10
# 3       None
# 4   06.09.10

# %%
# extract the first date mentioned from the suspected columns
start_dates = []

for i, row in outbreaks.iterrows():
    dates = row[12:]
    start_date = next((i for i in dates if i is not None), None)
    start_dates.append(start_date)

# %%
outbreaks['start_date'] = start_dates

# %%
# check extracted start dates
outbreaks['start_date'].unique()
# Out:
# array(['13.07.10', '20.07.10', '10.09.10', None, '06.09.10', '24.09.10',
#        '03.07.10', '24.06.10', '29.06.10', '27.06.10', '19.12.10',
#        '29.07.10', '15.06.10', '04.11.10', '10.05.10', '21.09.10',
#        '28.12.09', '11.12.10', '24.01.10', '17.08.10', '16.07.10',
#        '27.05.10', '30.05.10', '22.10.10', '03.10.10', '20.08.10',
#        '18.08.10', '28.02.10', '04.06.10', '24.10.10', '22.06.10',
#        '29.11.10', '16.08.10', '06.08.10', '12.05.10', '03.05.10',
#        '23.04.10', '12.07.10', '06.07.10', '06.06.11', '08.07.11',
#        '27.06.11', '26.06.11', '03.03.11', '13.07.11', '15.10.11',
#        '24.10.11', '23.09.11', '01.10.11', '08.03.11', '08.12.11',
#        '11.12.11', '23.04.11', '18.04.11', '24.04.11', '07.04.11',
#        '20.06.11', '14.06.11', '20.02.11', '11.07.11', '23.07.11',
#        '20.04.11', '07.10.11', '03.01.11', '12.12.11', '14.10.11',
#        '09.09.11', '22.08.11', '18.08.11', '20.08.11', '16.08.11',
#        '21.08.11', '14.08.11', '20.03.11', '15.09.11', '12.09.11',
#        '27.08.11', '03.09.11', '29.08.11', '11.08.11', '22.07.11',
#        '03.07.11', '21.06.11', '19.11.11', '18.05.11', '24.05.11',
#        '04.05.11', '02.06.11', '04.08.11', '01.08.11', '27.01.11',
#        '08.05.11', '05/06/12', '09/06/12', '04/11/12', '12/10/12',
#        '27/04/12', '24/04/12', '07/08/12', '10/08/12', '05/08/12',
#        '26/01/12', '19/01/12', '3/05/12', '07/11/12', '26/03/12',
#        '03/08/12', '30/09/12', '28/09/12', '16/10/12', '18/06/12',
#        '13/06/12', '22/06/12', '11/06/12', '16/07/12', '12/07/12',
#        '21/07/12', '18/07/12', '15/07/12', '26/02/12', '03/01/12',
#        '01/01/12', '25/05/12', '16/05/12', '19/05/12', '15/05/12',
#        '23/07/12', '24/07/12', '26/07/12', '22/07/12', '17/07/12',
#        '23/08/12', '20/08/12', '19/08/12', '21/06/12', '23/06/12',
#        '27/06/12', '29/05/12', '06/06/12', '02/07/12', '08/07/12',
#        '30/06/12', '01/07/12', '03/07/12', '24/01/12', '17/10/12',
#        '01/09/12', '15/01/12', '12/09/12', '19/09/12', '10/09/12',
#        '04/04/12', '06/04/12', '11/09/12', '10/06/12', '04/05/12',
#        '06/05/12', '08/05/12', '05/05/12', '03/05/12', '09/05/12',
#        '01/05/12', '10/07/12', '06/07/12', '13.03.12', '20/12/12',
#        '22/05/12', '04/09/12', '08/09/12', '27/08/12', '25/08/12',
#        '17/08/12', '06/08/12', '28/01/12', '21/11/13', '30/10/13',
#        '04/11/13', '05/11/13', '24/10/13', '25/10/13', '07/12/13',
#        '17/07/13', '10/07/13', '28/08/13', '29/08/13', '11/08/13',
#        '16-07-16', '04-07-16', '04-05-16', '02-05-16', '05-05-16',
#        '06-09-16', '24-09-16', '17-10-16', '25-07-16', '22-07-16',
#        '28-07-16', '27-07-16', '29-07-16', '09-07-16', '09-06-16',
#        '26-10-16', '13-05-16', '14-05-16', '02-08-16', '03-08-16',
#        '30-07-16', '06-05-16', '27-01-16', '13-06-16', '18-07-16',
#        '31-07-16', '08-06-16', '23-03-16', '13-07-17', '12-07-17',
#        '14-08-17', '23-10-17', '26-05-17', '19-01-17', '16-08-17',
#        '01-08-17', '02-08-17', '10-11-17', '16-06-17', '23-06-17',
#        '14-06-17', '06-07-17', '28-06-17', '13-12-17', '30-06-17',
#        '14-10-17', '24-08-17', '01-03-17', '20-05-17', '11-07-17',
#        '22-08-17', '27-07-17', '25-07-17', '20-07-17', '30-07-17',
#        '02-11-18', '26-10-18', '02-05-18', '13-07-18', '08-07-18',
#        '14-07-18', '09-09-18', '15-10-18', '23-05-18', '27-08-18',
#        '28-08-18', '29-08-18', '09-02-18', '04-07-18', '26-06-18',
#        '17-04-18', '02-10-18', '20-07-18', '21-07-18', '20-08-18',
#        '23-08-18', '05-04-18', '10-03-18', '21-06-18', '23-06-18',
#        '04-08-18', '07-05-18', '22-07-18', '12-09-18', '02-06-18',
#        '01-02-18', '06-07-18'], dtype=object)

# %% [markdown]
# We see that the dates appear in many different formats. Thus, we should harmonise them.

# %%
# drop all rows that do not contain any date
outbreaks = outbreaks.loc[outbreaks['start_date'].notnull()].reset_index(drop=True)

# %%
# harmonise date formats to extract year
outbreaks['year'] = outbreaks['start_date'].apply(lambda x: x.split('.')[2] if '.' in x
                                                  else (x.split('/')[2] if '/' in x
                                                        else (x.split('-')[2] if '-' in x
                                                              else x)))

# %%
# further harmonise date formats and extract years
outbreaks['year'] = outbreaks['year'].str.pad(width=3, side='left', fillchar='0')
outbreaks['year'] = outbreaks['year'].str.pad(width=4, side='left', fillchar='2')
outbreaks['year'] = outbreaks['year'].astype(np.int64)

# %%
# check years
outbreaks['year'].unique()
# Out:
# array([2010, 2009, 2011, 2012, 2013, 2014, 2015, 2019, 2016, 2017, 2018])

# %%
# check case where there seems to be a typo
outbreaks.loc[(outbreaks['col9'] == '2015/39th_2015.pdf') & (outbreaks['year'] == 2019)]
# Out:
#           col0      col1  col2     col3 col4 col5      col6      col7  col8  \
# 393  karnataka  bagalkot  vii.  cholera   66   00  20-09-19  25-09-19  None
#
#                    col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 393  2015/39th_2015.pdf    cholera         1       None   20-09-19   25-09-19
#
#     start_date  year
# 393   20-09-19  2019

# %%
# fix typo
outbreaks.loc[(outbreaks['col9'] == '2015/39th_2015.pdf') & (outbreaks['year'] == 2019), 'year'] = 2015

# %%
# harmonise date formats to extract month
outbreaks['month'] = outbreaks['start_date'].apply(lambda x: x.split('.')[1] if '.' in x
                                                   else (x.split('/')[1] if '/' in x
                                                         else (x.split('-')[1] if '-' in x
                                                               else x)))

# %%
# cast month to integer
outbreaks['month'] = outbreaks['month'].astype(np.int64)

# %%
# check months
outbreaks['month'].unique()
# Out:
# array([ 7,  9,  6, 12, 11,  5,  1,  8, 10,  2,  4,  3])

# %%
outbreaks.shape
# Out:
# (587, 18)

# %%
# drop all rows that do not contain data from 2010 to 2018
outbreaks = outbreaks.loc[outbreaks['year'].isin(years)].reset_index(drop=True)

# %%
outbreaks.shape
# Out:
# (586, 18)

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
# 4     water.    bharuch    xii.  cholera       2    /         0  24.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/41st_2010.pdf    cholera         1       None       None
#
#   col7_clean start_date  year  month
# 0       None   13.07.10  2010      7
# 1       None   20.07.10  2010      7
# 2   10.09.10   10.09.10  2010      9
# 3   06.09.10   06.09.10  2010      9
# 4   24.09.10   24.09.10  2010      9

# %%
outbreaks.tail()
# Out:
#                     col0                col1        col2     col3 col4 col5  \
# 581  pb/ldh/2018/44/1456              punjab    ludhiana  cholera   12   00
# 582                 west              bengal   bardhaman  cholera   69   00
# 583               basis.  ch/chd/2018/22/760  chandigarh  cholera   01   00
# 584  kl/mlp/2018/08/0241              kerala  malappuram  cholera   03   00
# 585                delhi               north       delhi  cholera   12   00
#
#          col6      col7  col8                col9 col3_clean  outbreak  \
# 581  12-09-18     under  None  2018/44th_2018.pdf    cholera         1
# 582  02-06-18  04-06-18  None  2018/23rd_2018.pdf    cholera         1
# 583  23-05-18     under  None  2018/23rd_2018.pdf    cholera         1
# 584  01-02-18     under  None   2018/8th_2018.pdf    cholera         1
# 585  06-07-18     under  None  2018/31st_2018.pdf    cholera         1
#
#     col5_clean col6_clean col7_clean start_date  year  month
# 581       None   12-09-18       None   12-09-18  2018      9
# 582       None   02-06-18   04-06-18   02-06-18  2018      6
# 583       None   23-05-18       None   23-05-18  2018      5
# 584       None   01-02-18       None   01-02-18  2018      2
# 585       None   06-07-18       None   06-07-18  2018      7

# %% [markdown]
# ## Map states, districts and location (geometry)

# %% [markdown]
# Next, we need to map states and districts to their geographic location. We do this with the help of the [Database of Global Administrative Areas](https://www.gadm.org/index.html). We download the Level 2 administrative zones for India and explore them before we extract the relevant information and merge it with the outbreaks data.

# %%
# !wget --recursive --no-directories --no-clobber --directory-prefix=../data/cholera_outbreaks https://biogeo.ucdavis.edu/data/gadm3.6/shp/gadm36_IND_shp.zip
# Out:
# File ‘../data/cholera_outbreaks/gadm36_IND_shp.zip’ already there; not retrieving.

# %%
# !unzip -u -d ../data/cholera_outbreaks/gadm36_IND_shp ../data/cholera_outbreaks/gadm36_IND_shp.zip
# Out:
# Archive:  ../data/cholera_outbreaks/gadm36_IND_shp.zip

# %%
path = '../data/cholera_outbreaks/gadm36_IND_shp'

# %%
file = 'gadm36_IND_2.shp'

# %%
india = gpd.read_file(os.path.join(path, file))

# %%
# check the data's crs
india.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
india.shape
# Out:
# (666, 14)

# %%
india.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 666 entries, 0 to 665
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GID_0      666 non-null    object
#  1   NAME_0     666 non-null    object
#  2   GID_1      666 non-null    object
#  3   NAME_1     666 non-null    object
#  4   NL_NAME_1  0 non-null      object
#  5   GID_2      666 non-null    object
#  6   NAME_2     666 non-null    object
#  7   VARNAME_2  190 non-null    object
#  8   NL_NAME_2  0 non-null      object
#  9   TYPE_2     666 non-null    object
#  10  ENGTYPE_2  666 non-null    object
#  11  CC_2       0 non-null      object
#  12  HASC_2     626 non-null    object
#  13  geometry   666 non-null    geometry
# dtypes: geometry(1), object(13)
# memory usage: 73.0+ KB

# %%
india.head()
# Out:
#   GID_0 NAME_0    GID_1               NAME_1 NL_NAME_1      GID_2  \
# 0   IND  India  IND.1_1  Andaman and Nicobar      None  IND.1.1_1
# 1   IND  India  IND.1_1  Andaman and Nicobar      None  IND.1.2_1
# 2   IND  India  IND.1_1  Andaman and Nicobar      None  IND.1.3_1
# 3   IND  India  IND.2_1       Andhra Pradesh      None  IND.2.1_1
# 4   IND  India  IND.2_1       Andhra Pradesh      None  IND.2.2_1
#
#                      NAME_2             VARNAME_2 NL_NAME_2    TYPE_2  \
# 0           Nicobar Islands                  None      None  District
# 1  North and Middle Andaman                  None      None  District
# 2             South Andaman                  None      None  District
# 3                 Anantapur  Anantpur, Ananthapur      None  District
# 4                  Chittoor       Chitoor|Chittor      None  District
#
#   ENGTYPE_2  CC_2    HASC_2                                           geometry
# 0  District  None  IN.AN.NI  MULTIPOLYGON (((93.78773 6.85264, 93.78849 6.8...
# 1  District  None  IN.AN.NM  MULTIPOLYGON (((92.93898 12.22386, 92.93916 12...
# 2  District  None  IN.AN.SA  MULTIPOLYGON (((92.47972 10.52056, 92.47945 10...
# 3  District  None  IN.AD.AN  POLYGON ((77.71420 13.76079, 77.71314 13.75074...
# 4  District  None  IN.AD.CH  POLYGON ((78.46293 12.63537, 78.46190 12.63228...

# %%
# select states, districts and geometry
states_districts = india[['NAME_1', 'NAME_2', 'geometry']].copy()

# %%
# rename columns
states_districts.columns = ['state', 'district', 'geometry']

# %%
# make states and districts lowercase to simplify the mapping
states_districts['state'] = states_districts['state'].str.lower()
states_districts['district'] = states_districts['district'].str.lower()

# %%
# create list with unique districts
districts = states_districts['district'].unique().tolist()

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
# 4     water.    bharuch    xii.  cholera       2    /         0  24.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/41st_2010.pdf    cholera         1       None       None
#
#   col7_clean start_date  year  month
# 0       None   13.07.10  2010      7
# 1       None   20.07.10  2010      7
# 2   10.09.10   10.09.10  2010      9
# 3   06.09.10   06.09.10  2010      9
# 4   24.09.10   24.09.10  2010      9

# %%
# remove all but alphanumeric characters from columns suspected to contain states and districts
for col in outbreaks.columns[0:3]:
    outbreaks[col+'_clean'] = outbreaks[col].apply(lambda x: re.sub('\W', '', x))
    outbreaks[col+'_clean'] = outbreaks[col+'_clean'].apply(lambda x: None if len(x) < 3 else x)

# %%
# harmonise district names in col1_clean to simplify mapping
outbreaks.loc[outbreaks['col1_clean'] == 'mahabubnagar', 'col1_clean'] = 'mahbubnagar'
outbreaks.loc[outbreaks['col1_clean'] == 'ahmedabad', 'col1_clean'] = 'ahmadabad'
outbreaks.loc[outbreaks['col1_clean'] == 'howrah', 'col1_clean'] = 'haora'
outbreaks.loc[outbreaks['col1_clean'] == 'hooghly', 'col1_clean'] = 'hugli'
outbreaks.loc[outbreaks['col1_clean'] == 'hoogly', 'col1_clean'] = 'hugli'
outbreaks.loc[outbreaks['col1_clean'] == 'villupuram', 'col1_clean'] = 'viluppuram'
outbreaks.loc[outbreaks['col1_clean'] == 'haridwar', 'col1_clean'] = 'hardwar'
outbreaks.loc[outbreaks['col1_clean'] == 'davangere', 'col1_clean'] = 'davanagere'
outbreaks.loc[outbreaks['col1_clean'] == 'davengere', 'col1_clean'] = 'davanagere'
outbreaks.loc[outbreaks['col1_clean'] == 'davangare', 'col1_clean'] = 'davanagere'
outbreaks.loc[outbreaks['col1_clean'] == 'tiruchirapalli', 'col1_clean'] = 'tiruchirappalli'
outbreaks.loc[outbreaks['col1_clean'] == 'darang', 'col1_clean'] = 'darrang'
outbreaks.loc[outbreaks['col1_clean'] == 'virudhunager', 'col1_clean'] = 'virudunagar'
outbreaks.loc[outbreaks['col1_clean'] == 'chikkaballapur', 'col1_clean'] = 'chikballapura'
outbreaks.loc[outbreaks['col1_clean'] == 'gondia', 'col1_clean'] = 'gondiya'
outbreaks.loc[outbreaks['col1_clean'] == 'purulia', 'col1_clean'] = 'puruliya'
outbreaks.loc[outbreaks['col1_clean'] == 'kalaburagi', 'col1_clean'] = 'gulbarga'
outbreaks.loc[outbreaks['col1_clean'] == 'kalburgi', 'col1_clean'] = 'gulbarga'
outbreaks.loc[outbreaks['col1_clean'] == 'berhampur', 'col1_clean'] = 'ganjam'
outbreaks.loc[outbreaks['col1_clean'] == 'sholapur', 'col1_clean'] = 'solapur'
outbreaks.loc[outbreaks['col1_clean'] == 'raigad', 'col1_clean'] = 'raigarh'
outbreaks.loc[outbreaks['col1_clean'] == 'panchmahal', 'col1_clean'] = 'panch mahals'
outbreaks.loc[outbreaks['col1_clean'] == 'sibsagar', 'col1_clean'] = 'sivasagar'
outbreaks.loc[outbreaks['col1_clean'] == 'sibsagar', 'col1_clean'] = 'kabeerdham'
outbreaks.loc[outbreaks['col1_clean'] == 'banaskantha', 'col1_clean'] = 'banas kantha'
outbreaks.loc[outbreaks['col1_clean'] == 'chamarajnagar', 'col1_clean'] = 'chamrajnagar'
outbreaks.loc[outbreaks['col1_clean'] == 'khargaon', 'col1_clean'] = 'west nimar'
outbreaks.loc[outbreaks['col1_clean'] == 'mysuru', 'col1_clean'] = 'mysore'
outbreaks.loc[outbreaks['col1_clean'] == 'mohali', 'col1_clean'] = 'sahibzada ajit singh nagar'
outbreaks.loc[outbreaks['col1_clean'] == 'delhi', 'col1_clean'] = 'west'
outbreaks.loc[outbreaks['col1_clean'] == 'kawardha', 'col1_clean'] = 'kabeerdham'
outbreaks.loc[outbreaks['col1_clean'] == 'chirtadurga', 'col1_clean'] = 'chitradurga'
outbreaks.loc[outbreaks['col1_clean'] == 'budgam', 'col1_clean'] = 'badgam'
outbreaks.loc[outbreaks['col1_clean'] == 'gulburga', 'col1_clean'] = 'gulbarga'
outbreaks.loc[outbreaks['col1_clean'] == 'jangir', 'col1_clean'] = 'janjgir-champa'
outbreaks.loc[outbreaks['col1_clean'] == 'kancheepuramsaidapet', 'col1_clean'] = 'kancheepuram'

# harmonise district names in col2_clean to simplify mapping
outbreaks.loc[outbreaks['col2_clean'] == 'thiruvannamalai', 'col2_clean'] = 'tiruvannamalai'
outbreaks.loc[outbreaks['col2_clean'] == 'raigad', 'col2_clean'] = 'raigarh'
outbreaks.loc[outbreaks['col2_clean'] == 'davangere', 'col2_clean'] = 'davanagere'
outbreaks.loc[outbreaks['col2_clean'] == 'sibsagar', 'col2_clean'] = 'sivasagar'
outbreaks.loc[outbreaks['col2_clean'] == 'sabarkantha', 'col2_clean'] = 'sabar kantha'

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
# 4     water.    bharuch    xii.  cholera       2    /         0  24.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/41st_2010.pdf    cholera         1       None       None
#
#   col7_clean start_date  year  month col0_clean col1_clean col2_clean
# 0       None   13.07.10  2010      7   himachal    pradesh     shimla
# 1       None   20.07.10  2010      7      alwar      sikar     jaipur
# 2   10.09.10   10.09.10  2010      9      assam  dibrugarh        xvi
# 3   06.09.10   06.09.10  2010      9  karnataka    belgaum        xxi
# 4   24.09.10   24.09.10  2010      9      water    bharuch        xii

# %%
outbreaks.columns[18:]
# Out:
# Index(['col0_clean', 'col1_clean', 'col2_clean'], dtype='object')

# %%
# extract district strings from columns suspected to contain districts
for col in outbreaks.columns[18:]:
    outbreaks[col+'_district'] = outbreaks[col].apply(lambda x: None if x is None else next((d for d in districts if x in str(d)), None))

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
# 4     water.    bharuch    xii.  cholera       2    /         0  24.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/41st_2010.pdf    cholera         1       None       None
#
#   col7_clean start_date  year  month col0_clean col1_clean col2_clean  \
# 0       None   13.07.10  2010      7   himachal    pradesh     shimla
# 1       None   20.07.10  2010      7      alwar      sikar     jaipur
# 2   10.09.10   10.09.10  2010      9      assam  dibrugarh        xvi
# 3   06.09.10   06.09.10  2010      9  karnataka    belgaum        xxi
# 4   24.09.10   24.09.10  2010      9      water    bharuch        xii
#
#   col0_clean_district col1_clean_district col2_clean_district
# 0                None                None              shimla
# 1               alwar               sikar              jaipur
# 2                None           dibrugarh                None
# 3                None             belgaum                None
# 4                None             bharuch                None

# %%
# select processed columns suspected to contain districts
district_cols = [col for col in outbreaks.columns if 'district' in col]

# %%
# extract districts from processed columns suspected to contain districts
outbreaks_districts = []

for i, row in outbreaks.iterrows():
    all_district_cols = row[district_cols]
    district = next((i for i in all_district_cols if i is not None), None)
    outbreaks_districts.append(district)

# %%
# create new column with extracted districts
outbreaks['district'] = outbreaks_districts

# %%
# manually map missing districts
outbreaks.loc[(outbreaks['col4'] == '110') & (outbreaks['col6'] == '25/10/13'), 'district'] = 'bankura'
outbreaks.loc[(outbreaks['col4'] == '50') & (outbreaks['col6'] == '25/10/13') & (outbreaks['col7'] == '28/10/13'), 'district'] = 'bankura'
outbreaks.loc[(outbreaks['col4'] == '23') & (outbreaks['col6'] == '23/10/13') & (outbreaks['col7'] == '23/10/13'), 'district'] = 'puruliya'
outbreaks.loc[(outbreaks['col4'] == '13') & (outbreaks['col6'] == '31/07/13') & (outbreaks['col7'] == '31/07/13'), 'district'] = 'puruliya'
outbreaks.loc[(outbreaks['col4'] == '33') & (outbreaks['col6'] == '01/06/13') & (outbreaks['col7'] == '08/06/13'), 'district'] = 'chitradurga'
outbreaks.loc[(outbreaks['col4'] == '88') & (outbreaks['col6'] == '05/05/13'), 'district'] = 'sangli'
outbreaks.loc[(outbreaks['col4'] == '60') & (outbreaks['col6'] == '01/05/13') & (outbreaks['col7'] == '02/05/13'), 'district'] = 'puruliya'
outbreaks.loc[(outbreaks['col4'] == '36') & (outbreaks['col6'] == '19/04/13'), 'district'] = 'davanagere'
outbreaks.loc[(outbreaks['col4'] == '161') & (outbreaks['col6'] == '27/08/12'), 'district'] = 'nagpur'
outbreaks.loc[(outbreaks['col4'] == '73') & (outbreaks['col6'] == '22/07/12') & (outbreaks['col7'] == '23/07/12'), 'district'] = 'bankura'
outbreaks.loc[(outbreaks['col4'] == '19') & (outbreaks['col6'] == '21/07/12') & (outbreaks['col7'] == '21/07/12'), 'district'] = 'chikmagalur'
outbreaks.loc[(outbreaks['col4'] == '21') & (outbreaks['col6'] == '06/07/12') & (outbreaks['col7'] == '12/07/12'), 'district'] = 'birbhum'
outbreaks.loc[(outbreaks['col4'] == '59') & (outbreaks['col6'] == '25/05/12') & (outbreaks['col7'] == '25/05/12'), 'district'] = 'tumkur'
outbreaks.loc[(outbreaks['col4'] == '8') & (outbreaks['col6'] == '03/05/12') & (outbreaks['col7'] == '07/05/12'), 'district'] = 'wayanad'
outbreaks.loc[(outbreaks['col4'] == '26') & (outbreaks['col7'] == '16.08.11'), 'district'] = 'birbhum'
outbreaks.loc[(outbreaks['col4'] == '86') & (outbreaks['col6'] == '25/10/13') & (outbreaks['col7'] == '28/10/13'), 'district'] = 'bankura'
outbreaks.loc[(outbreaks['col4'] == '25') & (outbreaks['col6'] == '19/05/12'), 'district'] = 'mandya'
outbreaks.loc[(outbreaks['col4'] == '12') & (outbreaks['col6'] == '13.03.12') & (outbreaks['col7'] == '14.03.12'), 'district'] = 'mysore'

# %%
outbreaks.head()
# Out:
#         col0       col1    col2     col3    col4 col5      col6      col7  \
# 0   himachal    pradesh  shimla  cholera    235/   1*  13.07.10     under
# 1     alwar,     sikar,  jaipur  cholera  1095/0    #  20.07.10     under
# 2      assam  dibrugarh    xvi.  cholera      10    /         0  10.09.10
# 3  karnataka    belgaum    xxi.  cholera      19    /         0  06.09.10
# 4     water.    bharuch    xii.  cholera       2    /         0  24.09.10
#
#    col8                col9 col3_clean  outbreak col5_clean col6_clean  \
# 0  None  2010/31st_2010.pdf    cholera         1       None   13.07.10
# 1  None  2010/31st_2010.pdf    cholera         1       None   20.07.10
# 2  None  2010/39th_2010.pdf    cholera         1       None       None
# 3  None  2010/39th_2010.pdf    cholera         1       None       None
# 4  None  2010/41st_2010.pdf    cholera         1       None       None
#
#   col7_clean start_date  year  month col0_clean col1_clean col2_clean  \
# 0       None   13.07.10  2010      7   himachal    pradesh     shimla
# 1       None   20.07.10  2010      7      alwar      sikar     jaipur
# 2   10.09.10   10.09.10  2010      9      assam  dibrugarh        xvi
# 3   06.09.10   06.09.10  2010      9  karnataka    belgaum        xxi
# 4   24.09.10   24.09.10  2010      9      water    bharuch        xii
#
#   col0_clean_district col1_clean_district col2_clean_district   district
# 0                None                None              shimla     shimla
# 1               alwar               sikar              jaipur      alwar
# 2                None           dibrugarh                None  dibrugarh
# 3                None             belgaum                None    belgaum
# 4                None             bharuch                None    bharuch

# %%
outbreaks.tail()
# Out:
#                     col0                col1        col2     col3 col4 col5  \
# 581  pb/ldh/2018/44/1456              punjab    ludhiana  cholera   12   00
# 582                 west              bengal   bardhaman  cholera   69   00
# 583               basis.  ch/chd/2018/22/760  chandigarh  cholera   01   00
# 584  kl/mlp/2018/08/0241              kerala  malappuram  cholera   03   00
# 585                delhi               north       delhi  cholera   12   00
#
#          col6      col7  col8                col9 col3_clean  outbreak  \
# 581  12-09-18     under  None  2018/44th_2018.pdf    cholera         1
# 582  02-06-18  04-06-18  None  2018/23rd_2018.pdf    cholera         1
# 583  23-05-18     under  None  2018/23rd_2018.pdf    cholera         1
# 584  01-02-18     under  None   2018/8th_2018.pdf    cholera         1
# 585  06-07-18     under  None  2018/31st_2018.pdf    cholera         1
#
#     col5_clean col6_clean col7_clean start_date  year  month       col0_clean  \
# 581       None   12-09-18       None   12-09-18  2018      9  pbldh2018441456
# 582       None   02-06-18   04-06-18   02-06-18  2018      6             west
# 583       None   23-05-18       None   23-05-18  2018      5            basis
# 584       None   01-02-18       None   01-02-18  2018      2  klmlp2018080241
# 585       None   06-07-18       None   06-07-18  2018      7            delhi
#
#          col1_clean  col2_clean col0_clean_district       col1_clean_district  \
# 581          punjab    ludhiana                None                      None
# 582          bengal   bardhaman       west godavari                      None
# 583  chchd201822760  chandigarh                None                      None
# 584          kerala  malappuram                None                      None
# 585           north       delhi                None  north and middle andaman
#
#     col2_clean_district                  district
# 581            ludhiana                  ludhiana
# 582                None             west godavari
# 583          chandigarh                chandigarh
# 584          malappuram                malappuram
# 585                None  north and middle andaman

# %%
outbreaks.shape
# Out:
# (586, 25)

# %%
# keep only rows that have a district
outbreaks = outbreaks.loc[outbreaks['district'].notnull()]

# %%
outbreaks.shape
# Out:
# (564, 25)

# %%
# map states and geometry to districts
outbreaks_mapped = pd.merge(states_districts, outbreaks, how='right', on='district')[['state', 'district', 'year', 'month', 'outbreak', 'geometry']].reset_index(drop=True)

# %%
outbreaks_mapped.shape
# Out:
# (573, 6)

# %%
outbreaks_mapped
# Out:
#                    state                  district  year  month  outbreak  \
# 0       himachal pradesh                    shimla  2010      7         1
# 1              rajasthan                     alwar  2010      7         1
# 2                  assam                 dibrugarh  2010      9         1
# 3              karnataka                   belgaum  2010      9         1
# 4                gujarat                   bharuch  2010      9         1
# ..                   ...                       ...   ...    ...       ...
# 568               punjab                  ludhiana  2018      9         1
# 569       andhra pradesh             west godavari  2018      6         1
# 570           chandigarh                chandigarh  2018      5         1
# 571               kerala                malappuram  2018      2         1
# 572  andaman and nicobar  north and middle andaman  2018      7         1
#
#                                               geometry
# 0    POLYGON ((77.51051 30.78743, 77.50089 30.79253...
# 1    POLYGON ((76.45745 27.08288, 76.44963 27.08627...
# 2    POLYGON ((95.37698 27.10218, 95.37267 27.10167...
# 3    POLYGON ((74.75089 15.49199, 74.74472 15.48939...
# 4    MULTIPOLYGON (((72.67597 21.44681, 72.67597 21...
# ..                                                 ...
# 568  POLYGON ((76.07124 30.56471, 76.06435 30.56714...
# 569  POLYGON ((81.81902 16.66214, 81.83632 16.64615...
# 570  POLYGON ((76.80293 30.67548, 76.79437 30.66932...
# 571  POLYGON ((76.06149 10.72085, 76.05975 10.71879...
# 572  MULTIPOLYGON (((92.93898 12.22386, 92.93916 12...
#
# [573 rows x 6 columns]

# %%
# find districts with identical names appearing in different states
duplicate_districts = states_districts['district'].value_counts()[states_districts['district'].value_counts() > 1].index.tolist()
outbreaks_mapped[outbreaks_mapped['district'].isin(duplicate_districts)].sort_values('district')
# Out:
#              state    district  year  month  outbreak  \
# 517    maharashtra  aurangabad  2017     11         1
# 446    maharashtra  aurangabad  2016      7         1
# 516          bihar  aurangabad  2017     11         1
# 445          bihar  aurangabad  2016      7         1
# 163   chhattisgarh     bijapur  2012      8         1
# 164      karnataka     bijapur  2012      8         1
# 199   chhattisgarh     bijapur  2012      7         1
# 200      karnataka     bijapur  2012      7         1
# 443   chhattisgarh     bijapur  2016      3         1
# 444      karnataka     bijapur  2016      3         1
# 475  uttar pradesh  pratapgarh  2016      7         1
# 474      rajasthan  pratapgarh  2016      7         1
# 72    chhattisgarh     raigarh  2011      7         1
# 100    maharashtra     raigarh  2011      7         1
# 99    chhattisgarh     raigarh  2011      7         1
# 73     maharashtra     raigarh  2011      7         1
# 390    maharashtra     raigarh  2015      3         1
# 389   chhattisgarh     raigarh  2015      3         1
#
#                                               geometry
# 517  POLYGON ((75.21554 19.55770, 75.20956 19.56258...
# 446  POLYGON ((75.21554 19.55770, 75.20956 19.56258...
# 516  POLYGON ((84.73145 25.05792, 84.73087 25.05387...
# 445  POLYGON ((84.73145 25.05792, 84.73087 25.05387...
# 163  POLYGON ((81.12064 19.25221, 81.12340 19.24678...
# 164  POLYGON ((76.41283 16.58693, 76.42019 16.57418...
# 199  POLYGON ((81.12064 19.25221, 81.12340 19.24678...
# 200  POLYGON ((76.41283 16.58693, 76.42019 16.57418...
# 443  POLYGON ((81.12064 19.25221, 81.12340 19.24678...
# 444  POLYGON ((76.41283 16.58693, 76.42019 16.57418...
# 475  POLYGON ((81.32791 25.81432, 81.33294 25.81743...
# 474  POLYGON ((74.93112 23.94491, 74.92985 23.94096...
# 72   POLYGON ((83.48308 21.63960, 83.48334 21.63717...
# 100  MULTIPOLYGON (((73.03819 18.05208, 73.03819 18...
# 99   POLYGON ((83.48308 21.63960, 83.48334 21.63717...
# 73   MULTIPOLYGON (((73.03819 18.05208, 73.03819 18...
# 390  MULTIPOLYGON (((73.03819 18.05208, 73.03819 18...
# 389  POLYGON ((83.48308 21.63960, 83.48334 21.63717...

# %% [markdown]
# We need to check to which state the duplicated districts actually belong.

# %%
outbreaks.loc[(outbreaks['district'] == 'aurangabad') & (outbreaks['month'] == 11)] # maharashtra
# Out:
#                     col0         col1        col2     col3  col4 col5  \
# 530  mh/agb/2017/46/1591  maharashtra  aurangabad  cholera  5825   00
#
#          col6      col7  col8                col9 col3_clean  outbreak  \
# 530  10-11-17  13-11-17  None  2017/46th_2017.pdf    cholera         1
#
#     col5_clean col6_clean col7_clean start_date  year  month       col0_clean  \
# 530       None   10-11-17   13-11-17   10-11-17  2017     11  mhagb2017461591
#
#       col1_clean  col2_clean col0_clean_district col1_clean_district  \
# 530  maharashtra  aurangabad                None                None
#
#     col2_clean_district    district
# 530          aurangabad  aurangabad

# %%
outbreaks.loc[(outbreaks['district'] == 'aurangabad') & (outbreaks['month'] == 7)] # maharashtra
# Out:
#                     col0         col1        col2     col3 col4 col5  \
# 448  mh/agb/2016/27/1592  maharashtra  aurangabad  cholera   09   01
#
#          col6      col7  col8                col9 col3_clean  outbreak  \
# 448  08-07-16  09-07-16  None  2016/27th_2016.pdf    cholera         1
#
#     col5_clean col6_clean col7_clean start_date  year  month       col0_clean  \
# 448       None   08-07-16   09-07-16   08-07-16  2016      7  mhagb2016271592
#
#       col1_clean  col2_clean col0_clean_district col1_clean_district  \
# 448  maharashtra  aurangabad                None                None
#
#     col2_clean_district    district
# 448          aurangabad  aurangabad

# %%
outbreaks.loc[(outbreaks['district'] == 'bijapur') & (outbreaks['month'] == 8)] # karnataka
# Out:
#        col0     col1 col2     col3 col4 col5      col6      col7  col8  \
# 162  given.  bijapur  xvi  cholera   85    0  20/08/12  20/08/12  None
#
#                    col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 162  2012/34th_2012.pdf    cholera         1       None   20/08/12   20/08/12
#
#     start_date  year  month col0_clean col1_clean col2_clean  \
# 162   20/08/12  2012      8      given    bijapur        xvi
#
#     col0_clean_district col1_clean_district col2_clean_district district
# 162                None             bijapur                None  bijapur

# %%
outbreaks.loc[(outbreaks['district'] == 'bijapur') & (outbreaks['month'] == 7)] # karnataka
# Out:
#           col0     col1 col2     col3 col4 col5      col6      col7  col8  \
# 197  imparted.  bijapur   xi  cholera   32    0  08/07/12  12/07/12  None
#
#                    col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 197  2012/28th_2012.pdf    cholera         1       None   08/07/12   12/07/12
#
#     start_date  year  month col0_clean col1_clean col2_clean  \
# 197   08/07/12  2012      7   imparted    bijapur       None
#
#     col0_clean_district col1_clean_district col2_clean_district district
# 197                None             bijapur                None  bijapur

# %%
outbreaks.loc[(outbreaks['district'] == 'bijapur') & (outbreaks['month'] == 8)] # karnataka
# Out:
#        col0     col1 col2     col3 col4 col5      col6      col7  col8  \
# 162  given.  bijapur  xvi  cholera   85    0  20/08/12  20/08/12  None
#
#                    col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 162  2012/34th_2012.pdf    cholera         1       None   20/08/12   20/08/12
#
#     start_date  year  month col0_clean col1_clean col2_clean  \
# 162   20/08/12  2012      8      given    bijapur        xvi
#
#     col0_clean_district col1_clean_district col2_clean_district district
# 162                None             bijapur                None  bijapur

# %%
outbreaks.loc[(outbreaks['district'] == 'pratapgarh') & (outbreaks['month'] == 7)] # rajasthan
# Out:
#                     col0       col1        col2     col3 col4 col5      col6  \
# 487  rj/pgr/2016/30/1789  rajasthan  pratapgarh  cholera   49   00  29-07-16
#
#          col7  col8                col9 col3_clean  outbreak col5_clean  \
# 487  29-07-16  None  2016/30th_2016.pdf    cholera         1       None
#
#     col6_clean col7_clean start_date  year  month       col0_clean col1_clean  \
# 487   29-07-16   29-07-16   29-07-16  2016      7  rjpgr2016301789  rajasthan
#
#      col2_clean col0_clean_district col1_clean_district col2_clean_district  \
# 487  pratapgarh                None                None          pratapgarh
#
#        district
# 487  pratapgarh

# %%
outbreaks.loc[(outbreaks['district'] == 'raigarh') & (outbreaks['month'] == 7)] # maharashtra
# Out:
#            col0    col1    col2     col3 col4 col5 col6      col7  col8  \
# 72  maharashtra  raigad    xxii  cholera   67    /    0  11.07.11  None
# 98        week.      11  raigad  cholera   94    /    0  11.07.11  None
#
#                   col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 72  2011/29th_2011.pdf    cholera         1       None       None   11.07.11
# 98  2011/30th_2011.pdf    cholera         1       None       None   11.07.11
#
#    start_date  year  month   col0_clean col1_clean col2_clean  \
# 72   11.07.11  2011      7  maharashtra    raigarh       xxii
# 98   11.07.11  2011      7         week       None    raigarh
#
#    col0_clean_district col1_clean_district col2_clean_district district
# 72                None             raigarh                None  raigarh
# 98                None                None             raigarh  raigarh

# %%
outbreaks.loc[(outbreaks['district'] == 'raigarh') & (outbreaks['month'] == 3)] # maharashtra
# Out:
#             col0    col1   col2     col3 col4 col5      col6   col7  col8  \
# 386  maharashtra  raigad  xxxi.  cholera   22   00  30/03/15  under  None
#
#                    col9 col3_clean  outbreak col5_clean col6_clean col7_clean  \
# 386  2015/16th_2015.pdf    cholera         1       None   30/03/15       None
#
#     start_date  year  month   col0_clean col1_clean col2_clean  \
# 386   30/03/15  2015      3  maharashtra    raigarh       xxxi
#
#     col0_clean_district col1_clean_district col2_clean_district district
# 386                None             raigarh                None  raigarh

# %% [markdown]
# We figured out to which state the duplicated districts actually belong and drop the rows that contain wrong data.

# %%
outbreaks_mapped = outbreaks_mapped.drop(outbreaks_mapped.loc[(outbreaks_mapped['state'].isin(['bihar', 'chhattisgarh', 'uttar pradesh'])) & (outbreaks_mapped['district'].isin(['aurangabad', 'bijapur', 'raigarh', 'pratapgarh']))].index)

# %%
outbreaks_mapped.shape
# Out:
# (564, 6)

# %%
outbreaks_mapped.drop_duplicates().shape
# Out:
# (466, 6)

# %% [markdown]
# Finally, we drop duplicated rows since we want to count an outbreak only once per district and month and save the data in shapefile format.

# %%
outbreaks_mapped.drop_duplicates().reset_index(drop=True).to_file('../data/cholera_outbreaks/monthly_cholera_outbreaks_per_district_2010_2018.shp')
